# %%
## Import Libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) ## Adjust Configuration of created plots

# %%
# pip install seaborn

# %%
## Read data

pd.read_csv(r'C:\Users\bhakt\OneDrive - Indiana University\Desktop\Portfolio\Projects\Python Movie Analysis\movies.csv')
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df = pd.read_csv(r'C:\Users\bhakt\OneDrive - Indiana University\Desktop\Portfolio\Projects\Python Movie Analysis\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
## Check for missing data
for column in df.columns:
    percent_missing = np.mean(df[column].isnull())*100
    print('{} - {}%'.format(column,percent_missing))
# Out:
# name - 0.0%
# rating - 1.004173187271779%
# genre - 0.0%
# year - 0.0%
# released - 0.02608242044861763%
# score - 0.03912363067292645%
# votes - 0.03912363067292645%
# director - 0.0%
# writer - 0.03912363067292645%
# star - 0.013041210224308816%
# country - 0.03912363067292645%
# budget - 28.31246739697444%
# gross - 2.464788732394366%
# company - 0.2217005738132499%
# runtime - 0.05216484089723526%

# %%
df = df.dropna()

# %%
## Check for missing data after dropna
for column in df.columns:
    percent_missing = np.mean(df[column].isnull())*100
    print('{} - {}%'.format(column,percent_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
## Check datatypes
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
## Convert Budget column from float to int
df['budget'] = df['budget'].astype('int64')

# %%
## Convert gross column from float to int
df['gross'] = df['gross'].astype('int64')

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
# ## Correcting the Year of Release
# df['correct_released_year'] = df['released'].astype(str).str[:4]

# Extracting the year from the 'released' column
df['corrected_release_year'] = df['released'].str.extract(r'\b(\d{4})\b')

# %%
# Drop column created incorrectly
# df.drop(columns=['corrected_release_year'], inplace=True)

# %%
df.head(20)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
## Check for missing data
for column in df.columns:
    if column == 'corrected_release_year':
        percent_missing = np.mean(df[column].isnull())*100
        print('{} - {}%'.format(column,percent_missing))
# Out:
# corrected_release_year - 0.0%

# %%
# Assuming your DataFrame is named df and the column you want to print unique values from is 'column_name'

unique_values2 = df['released'].unique()
for value in unique_values2:
    print(value)
# Out:
# June 13, 1980 (United States)
# July 2, 1980 (United States)
# June 20, 1980 (United States)
# July 25, 1980 (United States)
# May 9, 1980 (United States)
# December 19, 1980 (United States)
# June 19, 1981 (United States)
# May 16, 1980 (United States)
# December 17, 1980 (United States)
# October 26, 1984 (United States)
# December 12, 1980 (United States)
# September 19, 1980 (United States)
# October 3, 1980 (United States)
# February 8, 1980 (United States)
# February 15, 1980 (United States)
# April 24, 1981 (United States)
# August 1, 1980 (United States)
# August 8, 1980 (United States)
# February 1, 1980 (United States)
# October 10, 1980 (United States)
# May 30, 1980 (United States)
# October 24, 1980 (United States)
# June 27, 1980 (United States)
# September 26, 1980 (United States)
# June 11, 1980 (United States)
# March 28, 1980 (United States)
# July 11, 1980 (United States)
# August 15, 1980 (United States)
# June 25, 1980 (United States)
# ...

# %%
unique_values = df['corrected_release_year'].unique()
print(unique_values)
# Out:
# ['1980' '1981' '1984' '1983' '1982' '1987' '1985' '1986' '1990' '1988'
#  '1992' '1989' '1991' '1999' '1994' '1993' '1995' '2001' '1996' '2000'
#  '1997' '1998' '2002' '2003' '2004' '2019' '2014' '2005' '2006' '2007'
#  '2008' '2010' '2009' '2013' '2011' '2016' '2015' '2012' '2017' '2018'
#  '2020']

# %%
# # Assuming your DataFrame is named df and you want to print unique values from 'column1' and corresponding values from 'column2'

# for value in df['released'].unique():
#     corresponding_values = df[df['released'] == value]['corrected_release_year']
#     print(f'{value}: {corresponding_values.values}')

# Initialize an empty dictionary to store the values
year_object = {}

# Iterate over unique values in 'released' column
for value in df['released'].unique():
    corresponding_values = df[df['released'] == value]['corrected_release_year'].values.tolist()
    year_object[value] = corresponding_values

# Print only the top 10 items
print("Top 10 entries in year_object:")
for key, value in list(year_object.items())[:10]:
    print(f"{key}: {value}")

# Optionally, you can access the top 10 items directly for further processing
top_10_year_object = dict(list(year_object.items())[:10])
# Out:
# Top 10 entries in year_object:
# June 13, 1980 (United States): ['1980', '1980']
# July 2, 1980 (United States): ['1980', '1980']
# June 20, 1980 (United States): ['1980', '1980', '1980']
# July 25, 1980 (United States): ['1980', '1980']
# May 9, 1980 (United States): ['1980', '1980']
# December 19, 1980 (United States): ['1980', '1980']
# June 19, 1981 (United States): ['1981', '1981']
# May 16, 1980 (United States): ['1980']
# December 17, 1980 (United States): ['1980']
# October 26, 1984 (United States): ['1984', '1984', '1984', '1984']

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False).head(10)
# Out:
#                                             name rating      genre  year  \
# 5445                                      Avatar  PG-13     Action  2009
# 7445                           Avengers: Endgame  PG-13     Action  2019
# 3045                                     Titanic  PG-13      Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# 7480                               The Lion King     PG  Animation  2019
# 6653                              Jurassic World  PG-13     Action  2015
# 6043                                The Avengers  PG-13     Action  2012
# 6646                                   Furious 7  PG-13     Action  2015
# 7494                                   Frozen II     PG  Animation  2019
#
#                                released  score      votes         director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0    James Cameron
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False).head(10)
# Out:
#                                             name rating      genre  year  \
# 5445                                      Avatar  PG-13     Action  2009
# 7445                           Avengers: Endgame  PG-13     Action  2019
# 3045                                     Titanic  PG-13      Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# 7480                               The Lion King     PG  Animation  2019
# 6653                              Jurassic World  PG-13     Action  2015
# 6043                                The Avengers  PG-13     Action  2012
# 6646                                   Furious 7  PG-13     Action  2015
# 7494                                   Frozen II     PG  Animation  2019
#
#                                released  score      votes         director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0    James Cameron
# ...

# %%
# Find duplicate rows
duplicate_rows = df[df.duplicated()]

# Print duplicate rows
if not duplicate_rows.empty:
    print("Duplicate Rows:")
    print(duplicate_rows)
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
# # Dropping duplicate rows
# df.drop_duplicates(inplace=True)

# df['company'] = df['company'].drop_duplicates()

# %%
## Scatter Plot - budget vs Gross
plt.scatter(x=df['budget'], y=df['gross'], color='orange')
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Film Budget')
plt.show()

# %%
## Scatter plot with regression line using seaborn for budget vs gross
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"orange"}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Selecting only the columns you want to include in the correlation analysis
columns_to_include = df.columns[df.columns != 'year']

# Calculate correlation matrix excluding the 'year' column
correlation_matrix = df[columns_to_include].corr(numeric_only= True)

# %%
## Corellation (Pearson corellation by default)
correlation_matrix
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
## kendall corellation
correlation_matrix_kendall = df[columns_to_include].corr(numeric_only= True, method='kendall')
correlation_matrix_kendall
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.350185  1.000000  0.346274  0.553625  0.205344
# budget  -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
## spearman corellation
correlation_matrix_spearman = df[columns_to_include].corr(numeric_only= True, method='spearman')
correlation_matrix_spearman
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.495409  1.000000  0.493461  0.745793  0.300621
# budget  -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
## We can observe high corellation between budget and gross

# %%
# ## Heatmap of pearson corellation matrix
# # corellation_matrix=df.corr(numeric_only= True)
# sns.heatmap(corellation_matrix, annot = True)
# plt.title('Corellation matrix for numeric features')
# plt.xlabel('Movie Features')
# plt.ylabel('Movie Features')
# plt.show()

# %%
corellation_matrix = df.drop(columns=['year']).corr(numeric_only= True)

# Create heatmap
sns.heatmap(corellation_matrix, annot=True)
plt.title('Correlation matrix for numeric features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
corr_pairs = corellation_matrix.unstack()
corr_pairs
# Out:
# score    score      1.000000
#          votes      0.474256
#          budget     0.072001
#          gross      0.222556
#          runtime    0.414068
# votes    score      0.474256
#          votes      1.000000
#          budget     0.439675
#          gross      0.614751
#          runtime    0.352303
# budget   score      0.072001
#          votes      0.439675
#          budget     1.000000
#          gross      0.740247
#          runtime    0.318695
# gross    score      0.222556
#          votes      0.614751
#          budget     0.740247
#          gross      1.000000
#          runtime    0.275796
# runtime  score      0.414068
#          votes      0.352303
#          budget     0.318695
#          gross      0.275796
#          runtime    1.000000
# dtype: float64

# %%
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# budget   score      0.072001
# score    budget     0.072001
#          gross      0.222556
# gross    score      0.222556
# runtime  gross      0.275796
# gross    runtime    0.275796
# budget   runtime    0.318695
# runtime  budget     0.318695
#          votes      0.352303
# votes    runtime    0.352303
# runtime  score      0.414068
# score    runtime    0.414068
# budget   votes      0.439675
# votes    budget     0.439675
#          score      0.474256
# score    votes      0.474256
# gross    votes      0.614751
# votes    gross      0.614751
# budget   gross      0.740247
# gross    budget     0.740247
# score    score      1.000000
# budget   budget     1.000000
# votes    votes      1.000000
# gross    gross      1.000000
# runtime  runtime    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross    votes      0.614751
# votes    gross      0.614751
# budget   gross      0.740247
# gross    budget     0.740247
# score    score      1.000000
# budget   budget     1.000000
# votes    votes      1.000000
# gross    gross      1.000000
# runtime  runtime    1.000000
# dtype: float64

# %%
# To check if the company has any corellation with gross income, we will perform the anova test
# Hypothesis:
# Ho:  There is no significant difference in the mean gross revenue among all the companies.
# H1:At least one of the companies has a significantly different mean gross revenue compared to the others.
from scipy.stats import f_oneway
# Group the gross revenue data by company
grouped_data = [group['gross'] for name, group in df.groupby('company')]
# Perform one-way ANOVA
anova_result = f_oneway(*grouped_data)

# Print ANOVA result
print("ANOVA Result:")
print("F-statistic:", anova_result.statistic)
print("p-value:", anova_result.pvalue)
# Out:
# ANOVA Result:
# F-statistic: 1.4806813328874362
# p-value: 4.327561282383927e-21

# %%
alpha = 0.05  # Chosen significance level
if anova_result.pvalue <= alpha:
    print("Reject the null hypothesis. The result is statistically significant.")
else:
    print("Fail to reject the null hypothesis. The result is not statistically significant.")
# Out:
# Reject the null hypothesis. The result is statistically significant.

# %%
# We can say that the significant difference in gross revenue among companies suggests that movies produced 
# by certain companies tend to make more money compared to movies produced by other companies.
